# %%
# !pip install pymongo

# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://axd240045:e0KP5QndVMqG3u8d@cluster0.ztex8.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Create a new client and connect to the server
client = MongoClient(uri)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client["CarDealershipDatabase"]
cars = db["cars"]
services = db["services"]
sales = db["sales"]
inventory = db["inventory"]

print(db.list_collection_names())
# Out:
# ['cars', 'services', 'sales', 'inventory']

# %% [markdown]
# # Insert cars with embeded model data

# %%
cars_data=[
    {
        "car_id": 1,
        "year": 2020,
        "price": 20000.00,
        "color": "White",
        "vin": "JTMZK33V876009879",
        "stock_status": "Available",
        "mileage":15000,
        "model": {
            "model_id": 1,
            "make": "Toyota",
            "model": "Corolla",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 2,
        "year": 2021,
        "price": 35000.00,
        "color": "Red",
        "vin": "1ZVBP8CF6B5123456",
        "stock_status": "Sold",
        "mileage": 5000,
        "model": {
            "model_id": 2,
            "make": "Ford",
            "model": "Mustang",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 3,
        "year": 2022,
        "price": 80000.00,
        "color": "Black",
        "vin": "5YJSA1E25FF100001",
        "stock_status": "In Stock",
        "mileage": 1200,
        "model": {
            "model_id": 3,
            "make": "Tesla",
            "model": "Model S",
            "engine_type": "Electric"
        }
    },
    {
        "car_id": 4,
        "year": 2019,
        "price": 18000.00,
        "color": "Blue",
        "vin": "19XFC2F59JE216546",
        "stock_status": "In Stock",
        "mileage": 12000,
        "model": {
            "model_id": 4,
            "make": "Honda",
            "model": "Civic",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 5,
        "year": 2021,
        "price": 40000.00,
        "color": "Yellow",
        "vin": "1G1F51R63J0108156",
        "stock_status": "Sold",
        "mileage": 7000,
        "model": {
            "model_id": 5,
            "make": "Chevrolet",
            "model": "Camaro",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 6,
        "year": 2021,
        "price": 60000.00,
        "color": "Silver",
        "vin": "WBAXH5C59F0K12345",
        "stock_status": "In Stock",
        "mileage": 8000,
        "model": {
            "model_id": 6,
            "make": "BMW",
            "model": "X5",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 7,
        "year": 2020,
        "price": 45000.00,
        "color": "Black",
        "vin": "WAUZZZF48HA123456",
        "stock_status": "In Stock",
        "mileage": 9000,
        "model": {
            "model_id": 7,
            "make": "Audi",
            "model": "A4",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 8,
        "year": 2019,
        "price": 55000.00,
        "color": "White",
        "vin": "WDBUF65J13B123456",
        "stock_status": "Sold",
        "mileage": 12000,
        "model": {
            "model_id": 8,
            "make": "Mercedes",
            "model": "C-Class",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 9,
        "year": 2022,
        "price": 70000.00,
        "color": "Red",
        "vin": "5YJ3E1EA1JF123456",
        "stock_status": "In Stock",
        "mileage": 1500,
        "model": {
            "model_id": 9,
            "make": "Tesla",
            "model": "Model 3",
            "engine_type": "Electric"
        }
    },
    {
        "car_id": 10,
        "year": 2018,
        "price": 32000.00,
        "color": "Blue",
        "vin": "JTEDS41A582345678",
        "stock_status": "Sold",
        "mileage": 18000,
        "model": {
            "model_id": 10,
            "make": "Toyota",
            "model": "Highlander",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 11,
        "year": 2020,
        "price": 25000.00,
        "color": "White",
        "vin": "1FMCU9GX5HUA12345",
        "stock_status": "In Stock",
        "mileage": 7500,
        "model": {
            "model_id": 11,
            "make": "Ford",
            "model": "Escape",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 12,
        "year": 2021,
        "price": 52000.00,
        "color": "Gray",
        "vin": "1GNFK13027J123456",
        "stock_status": "In Stock",
        "mileage": 8000,
        "model": {
            "model_id": 12,
            "make": "Chevrolet",
            "model": "Tahoe",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 13,
        "year": 2019,
        "price": 27000.00,
        "color": "Silver",
        "vin": "1HGCP2F3XAA123456",
        "stock_status": "Sold",
        "mileage": 10000,
        "model": {
            "model_id": 13,
            "make": "Honda",
            "model": "Accord",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 14,
        "year": 2017,
        "price": 18000.00,
        "color": "Black",
        "vin": "1N4AL3AP8DC123456",
        "stock_status": "In Stock",
        "mileage": 6500,
        "model": {
            "model_id": 14,
            "make": "Nissan",
            "model": "Altima",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 15,
        "year": 2018,
        "price": 24000.00,
        "color": "Green",
        "vin": "5XYPGDA54HG123456",
        "stock_status": "Sold",
        "mileage": 11500,
        "model": {
            "model_id": 15,
            "make": "Kia",
            "model": "Sorento",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 16,
        "year": 2022,
        "price": 110000.00,
        "color": "Black",
        "vin": "1MBEJXXJXPN123456",
        "stock_status": "In Stock",
        "mileage": 5000,
        "model": {
            "model_id": 16,
            "make": "Mercedes-Benz",
            "model": "S-Class",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 17,
        "year": 2021,
        "price": 100000.00,
        "color": "White",
        "vin": "2BMWJXXJXPN123457",
        "stock_status": "In Stock",
        "mileage": 3000,
        "model": {
            "model_id": 17,
            "make": "BMW",
            "model": "7 Series",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 18,
        "year": 2022,
        "price": 105000.00,
        "color": "Silver",
        "vin": "3AUDIXXJXPN123458",
        "stock_status": "In Stock",
        "mileage": 2500,
        "model": {
            "model_id": 18,
            "make": "Audi",
            "model": "A8",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 19,
        "year": 2021,
        "price": 120000.00,
        "color": "Red",
        "vin": "4PORSCHEXXJXPN123459",
        "stock_status": "In Stock",
        "mileage": 4000,
        "model": {
            "model_id": 19,
            "make": "Porsche",
            "model": "Panamera",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 20,
        "year": 2020,
        "price": 90000.00,
        "color": "Blue",
        "vin": "5LEXUSXXJXPN123460",
        "stock_status": "In Stock",
        "mileage": 7000,
        "model": {
            "model_id": 20,
            "make": "Lexus",
            "model": "LS",
            "engine_type": "Hybrid"
        }
    },
    {
        "car_id": 21,
        "year": 2019,
        "price": 85000.00,
        "color": "Green",
        "vin": "6JAGUARXXJXPN123461",
        "stock_status": "Out of Stock",
        "mileage": 15000,
        "model": {
            "model_id": 21,
            "make": "Jaguar",
            "model": "XJ",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 26,
        "year": 2022,
        "price": 20000.00,
        "color": "Light Blue",
        "vin": "1FIATXXJXPN123491",
        "stock_status": "In Stock",
        "mileage": 1500,
        "model": {
            "model_id": 26,
            "make": "Mini",
            "model": "Cooper",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 27,
        "year": 2021,
        "price": 25000.00,
        "color": "British Racing Green",
        "vin": "2MINIXXJXPN123492",
        "stock_status": "In Stock",
        "mileage": 2000,
        "model": {
            "model_id": 27,
            "make": "Honda",
            "model": "HR-V",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 28,
        "year": 2022,
        "price": 23000.00,
        "color": "Dark Gray",
        "vin": "3HONDAHRVXXJXPN123493",
        "stock_status": "In Stock",
        "mileage": 3000,
        "model": {
            "model_id": 28,
            "make": "Nissan",
            "model": "Kicks",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 29,
        "year": 2021,
        "price": 21500.00,
        "color": "Sunset Orange",
        "vin": "4NISSANKICKSXXJXPN123494",
        "stock_status": "In Stock",
        "mileage": 4000,
        "model": {
            "model_id": 29,
            "make": "Toyota",
            "model": "C-HR",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 30,
        "year": 2022,
        "price": 24000.00,
        "color": "Purple",
        "vin": "5TOYOTACHRXXJXPN123495",
        "stock_status": "In Stock",
        "mileage": 3500,
        "model": {
            "model_id": 30,
            "make": "Hyundai",
            "model": "Venue",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 31,
        "year": 2022,
        "price": 19000.00,
        "color": "Teal",
        "vin": "6HYUNDAIVENUEXXJXPN123496",
        "stock_status": "In Stock",
        "mileage": 500,
        "model": {
            "model_id": 31,
            "make": "Kia",
            "model": "Soul",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 32,
        "year": 2021,
        "price": 21000.00,
        "color": "Bright Yellow",
        "vin": "7KIASOULXXJXPN123497",
        "stock_status": "In Stock",
        "mileage": 2500,
        "model": {
            "model_id": 32,
            "make": "Chevrolet",
            "model": "Spark",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 33,
        "year": 2022,
        "price": 15000.00,
        "color": "Red",
        "vin": "8CHEVYSXXJXPN123498",
        "stock_status": "In Stock",
        "mileage": 600,
        "model": {
            "model_id": 33,
            "make": "Mazda",
            "model": "CX-30",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 34,
        "year": 2021,
        "price": 26000.00,
        "color": "White",
        "vin": "9MAZDACX30XXJXPN123499",
        "stock_status": "In Stock",
        "mileage": 3000,
        "model": {
            "model_id": 34,
            "make": "Subaru",
            "model": "Crosstrek",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 35,
        "year": 2022,
        "price": 24000.00,
        "color": "Orange",
        "vin": "0SUBARUCROSSTREKXXJXPN123500",
        "stock_status": "In Stock",
        "mileage": 1500,
        "model": {
            "model_id": 35,
            "make": "Volkswagen",
            "model": "Tiguan",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 36,
        "year": 2021,
        "price": 28000.00,
        "color": "Dark Blue",
        "vin": "1VOLKSTIGUANXXJXPN123501",
        "stock_status": "In Stock",
        "mileage": 4000,
        "model": {
            "model_id": 36,
            "make": "Chrysler",
            "model": "Pacifica",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 37,
        "year": 2022,
        "price": 35000.00,
        "color": "Silver",
        "vin": "2CHRYSLERPACIFICAXXJXPN123502",
        "stock_status": "In Stock",
        "mileage": 2000,
        "model": {
            "model_id": 37,
            "make": "Dodge",
            "model": "Journey",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 38,
        "year": 2021,
        "price": 24000.00,
        "color": "Black",
        "vin": "3DODGEJOURNEYXXJXPN123503",
        "stock_status": "In Stock",
        "mileage": 3000,
        "model": {
            "model_id": 38,
            "make": "Nissan",
            "model": "Rogue",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 39,
        "year": 2022,
        "price": 28000.00,
        "color": "Gray",
        "vin": "4FORDESCAPEXXJXPN123504",
        "stock_status": "In Stock",
        "mileage": 1000,
        "model": {
            "model_id": 39,
            "make": "Toyota",
            "model": "Yaris",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 40,
        "year": 2021,
        "price": 29000.00,
        "color": "Dark Green",
        "vin": "5NISSANROGUEXXJXPN123505",
        "stock_status": "In Stock",
        "mileage": 1500,
        "model": {
            "model_id": 40,
            "make": "Honda",
            "model": "Fit",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 41,
        "year": 2022,
        "price": 18500.00,
        "color": "Black",
        "vin": "1TOYOTAYARISXXJXPN123506",
        "stock_status": "In Stock",
        "mileage": 1200,
        "model": {
            "model_id": 41,
            "make": "Hyundai",
            "model": "Accent",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 42,
        "year": 2021,
        "price": 19000.00,
        "color": "Red",
        "vin": "2HONDAFITXXJXPN123507",
        "stock_status": "In Stock",
        "mileage": 1500,
        "model": {
            "model_id": 42,
            "make": "Kia",
            "model": "Rio",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 43,
        "year": 2022,
        "price": 17500.00,
        "color": "Silver",
        "vin": "3HYUNDAIACXXJXPN123508",
        "stock_status": "In Stock",
        "mileage": 800,
        "model": {
            "model_id": 43,
            "make": "Ford",
            "model": "Fiesta",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 44,
        "year": 2021,
        "price": 18000.00,
        "color": "White",
        "vin": "4KIARIOXXJXPN123509",
        "stock_status": "In Stock",
        "mileage": 700,
        "model": {
            "model_id": 44,
            "make": "Chevrolet",
            "model": "Malibu",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 45,
        "year": 2022,
        "price": 17000.00,
        "color": "Blue",
        "vin": "5FORDFIESTAXXJXPN123510",
        "stock_status": "In Stock",
        "mileage": 500,
        "model": {
            "model_id": 45,
            "make": "Subaru",
            "model": "Legacy",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 46,
        "year": 2021,
        "price": 21000.00,
        "color": "Dark Green",
        "vin": "6CHEVYMALIBUXXJXPN123511",
        "stock_status": "In Stock",
        "mileage": 2000,
        "model": {
            "model_id": 46,
            "make": "Volkswagen",
            "model": "Golf",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 47,
        "year": 2022,
        "price": 24000.00,
        "color": "Maroon",
        "vin": "7SUBARULEGACYXXJXPN123512",
        "stock_status": "In Stock",
        "mileage": 1300,
        "model": {
            "model_id": 47,
            "make": "Mazda",
            "model": "CX-5",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 48,
        "year": 2021,
        "price": 23000.00,
        "color": "Bronze",
        "vin": "8NISSANALTIMAXXJXPN123513",
        "stock_status": "In Stock",
        "mileage": 1100,
        "model": {
            "model_id": 48,
            "make": "Dodge",
            "model": "Challenger",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 49,
        "year": 2022,
        "price": 25000.00,
        "color": "Yellow",
        "vin": "9VOLKSWAGENGOLFXXJXPN123514",
        "stock_status": "In Stock",
        "mileage": 400,
        "model": {
            "model_id": 49,
            "make": "Chevrolet",
            "model": "Traverse",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 50,
        "year": 2021,
        "price": 29000.00,
        "color": "Gray",
        "vin": "0MAZDACX5XXJXPN123515",
        "stock_status": "In Stock",
        "mileage": 1700,
        "model": {
            "model_id": 50,
            "make": "Jeep",
            "model": "Renegade",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 51,
        "year": 2022,
        "price": 31000.00,
        "color": "Black",
        "vin": "1DODGECHALLENGERXXJXPN123516",
        "stock_status": "In Stock",
        "mileage": 600,
        "model": {
            "model_id": 51,
            "make": "Hyundai",
            "model": "Tucson",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 52,
        "year": 2021,
        "price": 33000.00,
        "color": "Red",
        "vin": "2CHEVYTRAVERSEXXJXPN123517",
        "stock_status": "In Stock",
        "mileage": 900,
        "model": {
            "model_id": 52,
            "make": "Ford",
            "model": "Bronco Sport",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 53,
        "year": 2022,
        "price": 27000.00,
        "color": "White",
        "vin": "3JEEPRENEGADEXXJXPN123518",
        "stock_status": "In Stock",
        "mileage": 1300,
        "model": {
            "model_id": 53,
            "make": "Nissan",
            "model": "Sentra",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 54,
        "year": 2021,
        "price": 31000.00,
        "color": "Blue",
        "vin": "4HYUNDAITUCSONXXJXPN123519",
        "stock_status": "In Stock",
        "mileage": 1500,
        "model": {
            "model_id": 54,
            "make": "Hyundai",
            "model": "Elantra",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 55,
        "year": 2022,
        "price": 33000.00,
        "color": "Green",
        "vin": "5FORDBRONCOSPORTXXJXPN123520",
        "stock_status": "In Stock",
        "mileage": 800,
        "model": {
            "model_id": 55,
            "make": "Ford",
            "model": "Fusion",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 56,
        "year": 2022,
        "price": 21000.00,
        "color": "Silver",
        "vin": "1TOYOTACOROLAXXJXPN123521",
        "stock_status": "In Stock",
        "mileage": 1200,
        "model": {
            "model_id": 56,
            "make": "Chevrolet",
            "model": "Impala",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 57,
        "year": 2021,
        "price": 22000.00,
        "color": "Black",
        "vin": "2HONDACIVICXXJXPN123522",
        "stock_status": "In Stock",
        "mileage": 1500,
        "model": {
            "model_id": 57,
            "make": "Kia",
            "model": "Forte",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 58,
        "year": 2022,
        "price": 20500.00,
        "color": "White",
        "vin": "3NISSANSENTRAXXJXPN123523",
        "stock_status": "In Stock",
        "mileage": 800,
        "model": {
            "model_id": 58,
            "make": "Mazda",
            "model": "3",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 59,
        "year": 2021,
        "price": 20000.00,
        "color": "Blue",
        "vin": "4HYUNDAIELANTRAXXJXPN123524",
        "stock_status": "In Stock",
        "mileage": 1000,
        "model": {
            "model_id": 59,
            "make": "Subaru",
            "model": "Impreza",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 60,
        "year": 2022,
        "price": 22500.00,
        "color": "Red",
        "vin": "5FORDFUSIONXXJXPN123525",
        "stock_status": "In Stock",
        "mileage": 600,
        "model": {
            "model_id": 60,
            "make": "Volkswagen",
            "model": "Jetta",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 61,
        "year": 2021,
        "price": 23500.00,
        "color": "Dark Green",
        "vin": "6CHEVYIMPALAXXJXPN123526",
        "stock_status": "In Stock",
        "mileage": 900,
        "model": {
            "model_id": 61,
            "make": "Chevrolet",
            "model": "Cruze",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 62,
        "year": 2022,
        "price": 21500.00,
        "color": "Gray",
        "vin": "7KIAFORTEXXJXPN123527",
        "stock_status": "In Stock",
        "mileage": 1100,
        "model": {
            "model_id": 62,
            "make": "Dodge",
            "model": "Charger",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 63,
        "year": 2021,
        "price": 23000.00,
        "color": "Yellow",
        "vin": "8MAZDA3XXJXPN123528",
        "stock_status": "In Stock",
        "mileage": 500,
        "model": {
            "model_id": 63,
            "make": "Hyundai",
            "model": "Kona",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 64,
        "year": 2022,
        "price": 24000.00,
        "color": "Orange",
        "vin": "9SUBARUIMPREZAXXJXPN123529",
        "stock_status": "In Stock",
        "mileage": 1300,
        "model": {
            "model_id": 64,
            "make": "Ford",
            "model": "Fusion",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 65,
        "year": 2021,
        "price": 22000.00,
        "color": "Purple",
        "vin": "0VOLKSWAGENJETTAXXJXPN123530",
        "stock_status": "In Stock",
        "mileage": 800,
        "model": {
            "model_id": 65,
            "make": "BMW",
            "model": "7 Series",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 66,
        "year": 2022,
        "price": 19500.00,
        "color": "Light Blue",
        "vin": "1CHEVYCRUZEXXJXPN123531",
        "stock_status": "In Stock",
        "mileage": 600,
        "model": {
            "model_id": 66,
            "make": "Land Rover",
            "model": "Range Rover",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 67,
        "year": 2021,
        "price": 27000.00,
        "color": "Dark Gray",
        "vin": "2DODGECHARGERXXJXPN123532",
        "stock_status": "In Stock",
        "mileage": 1200,
        "model": {
            "model_id": 67,
            "make": "Toyota",
            "model": "Corolla",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 68,
        "year": 2022,
        "price": 23000.00,
        "color": "Teal",
        "vin": "3KIASOULXXJXPN123533",
        "stock_status": "In Stock",
        "mileage": 400,
        "model": {
            "model_id": 68,
            "make": "Volkswagen",
            "model": "Tiguan",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 69,
        "year": 2021,
        "price": 25000.00,
        "color": "Brown",
        "vin": "4HYUNDAIKONAXXJXPN123534",
        "stock_status": "In Stock",
        "mileage": 900,
        "model": {
            "model_id": 69,
            "make": "Nissan",
            "model": "Altima",
            "engine_type": "Gasoline"
        }
    },
    {
        "car_id": 70,
        "year": 2022,
        "price": 26000.00,
        "color": "Champagne",
        "vin": "5FORDESCAPEXXJXPN123535",
        "stock_status": "In Stock",
        "mileage": 1100,
        "model": {
            "model_id": 70,
            "make": "Dodge",
            "model": "Journey",
            "engine_type": "Gasoline"
        }
    }

]

cars.insert_many(cars_data)
# Out:
# InsertManyResult([ObjectId('6750e49ba07ee9b74479edc8'), ObjectId('6750e49ba07ee9b74479edc9'), ObjectId('6750e49ba07ee9b74479edca'), ObjectId('6750e49ba07ee9b74479edcb'), ObjectId('6750e49ba07ee9b74479edcc'), ObjectId('6750e49ba07ee9b74479edcd'), ObjectId('6750e49ba07ee9b74479edce'), ObjectId('6750e49ba07ee9b74479edcf'), ObjectId('6750e49ba07ee9b74479edd0'), ObjectId('6750e49ba07ee9b74479edd1'), ObjectId('6750e49ba07ee9b74479edd2'), ObjectId('6750e49ba07ee9b74479edd3'), ObjectId('6750e49ba07ee9b74479edd4'), ObjectId('6750e49ba07ee9b74479edd5'), ObjectId('6750e49ba07ee9b74479edd6'), ObjectId('6750e49ba07ee9b74479edd7'), ObjectId('6750e49ba07ee9b74479edd8'), ObjectId('6750e49ba07ee9b74479edd9'), ObjectId('6750e49ba07ee9b74479edda'), ObjectId('6750e49ba07ee9b74479eddb'), ObjectId('6750e49ba07ee9b74479eddc'), ObjectId('6750e49ba07ee9b74479eddd'), ObjectId('6750e49ba07ee9b74479edde'), ObjectId('6750e49ba07ee9b74479eddf'), ObjectId('6750e49ba07ee9b74479ede0'), ObjectId('6750e49ba07ee9b74479
# ...

# %% [markdown]
# # Insert services with embedded technician data

# %%
service_data=[
    {
        "service_id": 1,
        "car_id": 1,
        "customer_id": 1,
        "service_date": "3/1/21",
        "service_type": "Oil Change",
        "cost": 50,
        "technician": {
            "technician_id": 1,
            "first_name": "Mike",
            "last_name": "Wrench",
            "email": "mike.wrench@carservice.com",
            "phone_number": "555-5555",
            "specialty": "Engine Repair"
        }
    },
    {
        "service_id": 2,
        "car_id": 2,
        "customer_id": 2,
        "service_date": "4/12/22",
        "service_type": "Tire Rotation",
        "cost": 30,
        "technician": {
            "technician_id": 2,
            "first_name": "Sam",
            "last_name": "Fixer",
            "email": "sam.fixer@carservice.com",
            "phone_number": "555-6666",
            "specialty": "Electrical"
        }
    },
    {
        "service_id": 3,
        "car_id": 3,
        "customer_id": 3,
        "service_date": "8/10/22",
        "service_type": "Brake Inspection",
        "cost": 100,
        "technician": {
            "technician_id": 1,
            "first_name": "Mike",
            "last_name": "Wrench",
            "email": "mike.wrench@carservice.com",
            "phone_number": "555-5555",
            "specialty": "Engine Repair"
        }
    },
    {
        "service_id": 4,
        "car_id": 4,
        "customer_id": 4,
        "service_date": "2/20/23",
        "service_type": "Battery Replacement",
        "cost": 150,
        "technician": {
            "technician_id": 2,
            "first_name": "Sam",
            "last_name": "Fixer",
            "email": "sam.fixer@carservice.com",
            "phone_number": "555-6666",
            "specialty": "Electrical"
        }
    },
    {
        "service_id": 5,
        "car_id": 5,
        "customer_id": 5,
        "service_date": "7/1/23",
        "service_type": "Transmission Repair",
        "cost": 400,
        "technician": {
            "technician_id": 1,
            "first_name": "Mike",
            "last_name": "Wrench",
            "email": "mike.wrench@carservice.com",
            "phone_number": "555-5555",
            "specialty": "Engine Repair"
        }
    },
    {
        "service_id": 6,
        "car_id": 1,
        "customer_id": 6,
        "service_date": "8/15/23",
        "service_type": "Oil Change",
        "cost": 50,
        "technician": {
            "technician_id": 1,
            "first_name": "Mike",
            "last_name": "Wrench",
            "email": "mike.wrench@carservice.com",
            "phone_number": "555-5555",
            "specialty": "Engine Repair"
        }
    },
    {
        "service_id": 7,
        "car_id": 2,
        "customer_id": 7,
        "service_date": "9/5/23",
        "service_type": "Engine Repair",
        "cost": 500,
        "technician": {
            "technician_id": 2,
            "first_name": "Sam",
            "last_name": "Fixer",
            "email": "sam.fixer@carservice.com",
            "phone_number": "555-6666",
            "specialty": "Electrical"
        }
    },
    {
        "service_id": 8,
        "car_id": 7,
        "customer_id": 8,
        "service_date": "7/20/22",
        "service_type": "Tire Replacement",
        "cost": 150,
        "technician": {
            "technician_id": 2,
            "first_name": "Sam",
            "last_name": "Fixer",
            "email": "sam.fixer@carservice.com",
            "phone_number": "555-6666",
            "specialty": "Electrical"
        }
    },
    {
        "service_id": 9,
        "car_id": 9,
        "customer_id": 9,
        "service_date": "3/11/23",
        "service_type": "Battery Replacement",
        "cost": 180,
        "technician": {
            "technician_id": 1,
            "first_name": "Mike",
            "last_name": "Wrench",
            "email": "mike.wrench@carservice.com",
            "phone_number": "555-5555",
            "specialty": "Engine Repair"
        }
    },
    {
        "service_id": 10,
        "car_id": 8,
        "customer_id": 10,
        "service_date": "8/5/21",
        "service_type": "Brake Service",
        "cost": 120,
        "technician": {
            "technician_id": 3,
            "first_name": "Emma",
            "last_name": "Stone",
            "email": "emma.stone@carservice.com",
            "phone_number": "555-7890",
            "specialty": "Brake Service"
        }
    },
    {
        "service_id": 11,
        "car_id": 6,
        "customer_id": 11,
        "service_date": "10/20/20",
        "service_type": "Engine Repair",
        "cost": 600,
        "technician": {
            "technician_id": 2,
            "first_name": "Sam",
            "last_name": "Fixer",
            "email": "sam.fixer@carservice.com",
            "phone_number": "555-6666",
            "specialty": "Electrical"
        }
    },
    {
        "service_id": 12,
        "car_id": 14,
        "customer_id": 12,
        "service_date": "12/25/19",
        "service_type": "Transmission Repair",
        "cost": 700,
        "technician": {
            "technician_id": 5,
            "first_name": "Rachel",
            "last_name": "Green",
            "email": "rachel.green@carservice.com",
            "phone_number": "555-8901",
            "specialty": "Transmission Repair"
        }
    },
    {
        "service_id": 13,
        "car_id": 11,
        "customer_id": 13,
        "service_date": "2/13/22",
        "service_type": "Air Filter Change",
        "cost": 50,
        "technician": {
            "technician_id": 4,
            "first_name": "Michael",
            "last_name": "Scott",
            "email": "michael.scott@carservice.com",
            "phone_number": "555-6789",
            "specialty": "Air Filter Change"
        }
    },
    {
        "service_id": 14,
        "car_id": 12,
        "customer_id": 14,
        "service_date": "9/15/23",
        "service_type": "Spark Plug Replacement",
        "cost": 80,
        "technician": {
            "technician_id": 3,
            "first_name": "Emma",
            "last_name": "Stone",
            "email": "emma.stone@carservice.com",
            "phone_number": "555-7890",
            "specialty": "Brake Service"
        }
    },
    {
        "service_id": 15,
        "car_id": 13,
        "customer_id": 15,
        "service_date": "4/18/21",
        "service_type": "Suspension Repair",
        "cost": 500,
        "technician": {
            "technician_id": 2,
            "first_name": "Sam",
            "last_name": "Fixer",
            "email": "sam.fixer@carservice.com",
            "phone_number": "555-6666",
            "specialty": "Electrical"
        }
    },
    {
        "service_id": 16,
        "car_id": 15,
        "customer_id": 16,
        "service_date": "3/25/23",
        "service_type": "Coolant Flush",
        "cost": 200,
        "technician": {
            "technician_id": 5,
            "first_name": "Rachel",
            "last_name": "Green",
            "email": "rachel.green@carservice.com",
            "phone_number": "555-8901",
            "specialty": "Transmission Repair"
        }
    },
    {
        "service_id": 17,
        "car_id": 10,
        "customer_id": 17,
        "service_date": "11/12/21",
        "service_type": "Tire Rotation",
        "cost": 60,
        "technician": {
            "technician_id": 1,
            "first_name": "Mike",
            "last_name": "Wrench",
            "email": "mike.wrench@carservice.com",
            "phone_number": "555-5555",
            "specialty": "Engine Repair"
        }
    }
]

services.insert_many(service_data)
# Out:
# InsertManyResult([ObjectId('6750e54aa07ee9b74479ee0a'), ObjectId('6750e54aa07ee9b74479ee0b'), ObjectId('6750e54aa07ee9b74479ee0c'), ObjectId('6750e54aa07ee9b74479ee0d'), ObjectId('6750e54aa07ee9b74479ee0e'), ObjectId('6750e54aa07ee9b74479ee0f'), ObjectId('6750e54aa07ee9b74479ee10'), ObjectId('6750e54aa07ee9b74479ee11'), ObjectId('6750e54aa07ee9b74479ee12'), ObjectId('6750e54aa07ee9b74479ee13'), ObjectId('6750e54aa07ee9b74479ee14'), ObjectId('6750e54aa07ee9b74479ee15'), ObjectId('6750e54aa07ee9b74479ee16'), ObjectId('6750e54aa07ee9b74479ee17'), ObjectId('6750e54aa07ee9b74479ee18'), ObjectId('6750e54aa07ee9b74479ee19'), ObjectId('6750e54aa07ee9b74479ee1a')], acknowledged=True)

# %% [markdown]
# # Insert sales with embedded salesperson details

# %%
sales_data = [
    {
        "sale_id": 1,
        "car_id": 2,
        "customer_id": 1,
        "sale_date": "8/21/21",
        "price": 35000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 1,
            "first_name": "Alice",
            "last_name": "Brown",
            "email": "alice.brown@example.com",
            "phone": "555-1111",
            "hire_date": "5/1/19",
            "total_sales": 50
        }
    },
    {
        "sale_id": 2,
        "car_id": 3,
        "customer_id": 2,
        "sale_date": "1/15/22",
        "price": 80000.00,
        "payment_method": "Financing",
        "salesperson": {
            "salesperson_id": 2,
            "first_name": "Bob",
            "last_name": "Johnson",
            "email": "bob.johnson@example.com",
            "phone": "555-2222",
            "hire_date": "6/15/20",
            "total_sales": 30
        }
    },
    {
        "sale_id": 3,
        "car_id": 1,
        "customer_id": 4,
        "sale_date": "3/18/23",
        "price": 20000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 1,
            "first_name": "Alice",
            "last_name": "Brown",
            "email": "alice.brown@example.com",
            "phone": "555-1111",
            "hire_date": "5/1/19",
            "total_sales": 50
        }
    },
    {
        "sale_id": 4,
        "car_id": 5,
        "customer_id": 6,
        "sale_date": "4/10/23",
        "price": 40000.00,
        "payment_method": "Credit Card",
        "salesperson": {
            "salesperson_id": 2,
            "first_name": "Bob",
            "last_name": "Johnson",
            "email": "bob.johnson@example.com",
            "phone": "555-2222",
            "hire_date": "6/15/20",
            "total_sales": 30
        }
    },
    {
        "sale_id": 5,
        "car_id": 4,
        "customer_id": 7,
        "sale_date": "5/25/23",
        "price": 18000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 1,
            "first_name": "Alice",
            "last_name": "Brown",
            "email": "alice.brown@example.com",
            "phone": "555-1111",
            "hire_date": "5/1/19",
            "total_sales": 50
        }
    },
    {
        "sale_id": 6,
        "car_id": 7,
        "customer_id": 8,
        "sale_date": "6/15/22",
        "price": 42000.00,
        "payment_method": "Financing",
        "salesperson": {
            "salesperson_id": 3,
            "first_name": "David",
            "last_name": "Clark",
            "email": "david.clark@example.com",
            "phone": "555-2345",
            "hire_date": "4/12/21",
            "total_sales": 25
        }
    },
    {
        "sale_id": 7,
        "car_id": 9,
        "customer_id": 9,
        "sale_date": "1/10/23",
        "price": 70000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 4,
            "first_name": "Sophia",
            "last_name": "Martinez",
            "email": "sophia.martinez@example.com",
            "phone": "555-6789",
            "hire_date": "8/24/18",
            "total_sales": 45
        }
    },
    {
        "sale_id": 8,
        "car_id": 8,
        "customer_id": 10,
        "sale_date": "9/21/21",
        "price": 54000.00,
        "payment_method": "Credit Card",
        "salesperson": {
            "salesperson_id": 5,
            "first_name": "James",
            "last_name": "Moore",
            "email": "james.moore@example.com",
            "phone": "555-5678",
            "hire_date": "2/19/19",
            "total_sales": 60
        }
    },
    {
        "sale_id": 9,
        "car_id": 6,
        "customer_id": 11,
        "sale_date": "12/13/22",
        "price": 62000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 6,
            "first_name": "William",
            "last_name": "Taylor",
            "email": "william.taylor@example.com",
            "phone": "555-7890",
            "hire_date": "3/10/20",
            "total_sales": 30
        }
    },
    {
        "sale_id": 10,
        "car_id": 14,
        "customer_id": 12,
        "sale_date": "2/14/23",
        "price": 18000.00,
        "payment_method": "Financing",
        "salesperson": {
            "salesperson_id": 7,
            "first_name": "Ava",
            "last_name": "Lee",
            "email": "ava.lee@example.com",
            "phone": "555-2347",
            "hire_date": "5/14/22",
            "total_sales": 15
        }
    },
    {
        "sale_id": 11,
        "car_id": 11,
        "customer_id": 13,
        "sale_date": "8/23/20",
        "price": 26000.00,
        "payment_method": "Credit Card",
        "salesperson": {
            "salesperson_id": 8,
            "first_name": "Daniel",
            "last_name": "Harris",
            "email": "daniel.harris@example.com",
            "phone": "555-9876",
            "hire_date": "11/25/20",
            "total_sales": 40
        }
    },
    {
        "sale_id": 12,
        "car_id": 12,
        "customer_id": 14,
        "sale_date": "11/15/22",
        "price": 51000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 9,
            "first_name": "Lucas",
            "last_name": "Wilson",
            "email": "lucas.wilson@example.com",
            "phone": "555-8902",
            "hire_date": "9/11/19",
            "total_sales": 50
        }
    },
    {
        "sale_id": 13,
        "car_id": 13,
        "customer_id": 15,
        "sale_date": "4/12/23",
        "price": 29000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 10,
            "first_name": "Emma",
            "last_name": "White",
            "email": "emma.white@example.com",
            "phone": "555-3457",
            "hire_date": "7/21/21",
            "total_sales": 35
        }
    },
    {
        "sale_id": 14,
        "car_id": 15,
        "customer_id": 16,
        "sale_date": "3/8/21",
        "price": 25000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 1,
            "first_name": "Alice",
            "last_name": "Brown",
            "email": "alice.brown@example.com",
            "phone": "555-1111",
            "hire_date": "5/1/19",
            "total_sales": 50
        }
    },
    {
        "sale_id": 15,
        "car_id": 10,
        "customer_id": 17,
        "sale_date": "5/17/21",
        "price": 34000.00,
        "payment_method": "Credit Card",
        "salesperson": {
            "salesperson_id": 2,
            "first_name": "Bob",
            "last_name": "Johnson",
            "email": "bob.johnson@example.com",
            "phone": "555-2222",
            "hire_date": "6/15/20",
            "total_sales": 30
        }
    },
    {
        "sale_id": 16,
        "car_id": 6,
        "customer_id": 18,
        "sale_date": "7/21/23",
        "price": 59000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 3,
            "first_name": "David",
            "last_name": "Clark",
            "email": "david.clark@example.com",
            "phone": "555-2345",
            "hire_date": "4/12/21",
            "total_sales": 25
        }
    },
    {
        "sale_id": 17,
        "car_id": 7,
        "customer_id": 19,
        "sale_date": "9/15/23",
        "price": 52000.00,
        "payment_method": "Credit Card",
        "salesperson": {
            "salesperson_id": 4,
            "first_name": "Sophia",
            "last_name": "Martinez",
            "email": "sophia.martinez@example.com",
            "phone": "555-6789",
            "hire_date": "8/24/18",
            "total_sales": 45
        }
    },
    {
        "sale_id": 18,
        "car_id": 9,
        "customer_id": 20,
        "sale_date": "6/24/23",
        "price": 73000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 5,
            "first_name": "James",
            "last_name": "Moore",
            "email": "james.moore@example.com",
            "phone": "555-5678",
            "hire_date": "2/19/19",
            "total_sales": 60
        }
    },
    {
        "sale_id": 19,
        "car_id": 8,
        "customer_id": 21,
        "sale_date": "5/10/22",
        "price": 54000.00,
        "payment_method": "Financing",
        "salesperson": {
            "salesperson_id": 6,
            "first_name": "William",
            "last_name": "Taylor",
            "email": "william.taylor@example.com",
            "phone": "555-7890",
            "hire_date": "3/10/20",
            "total_sales": 30
        }
    },
    {
        "sale_id": 20,
        "car_id": 15,
        "customer_id": 22,
        "sale_date": "11/11/21",
        "price": 24000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 7,
            "first_name": "Ava",
            "last_name": "Lee",
            "email": "ava.lee@example.com",
            "phone": "555-2347",
            "hire_date": "5/14/22",
            "total_sales": 15
        }
    },
    {
        "sale_id": 21,
        "car_id": 5,
        "customer_id": 10,
        "sale_date": "3/15/24",
        "price": 20000.00,
        "payment_method": "Credit Card",
        "salesperson": {
            "salesperson_id": 2,
            "first_name": "Bob",
            "last_name": "Johnson",
            "email": "bob.johnson@example.com",
            "phone": "555-2222",
            "hire_date": "6/15/20",
            "total_sales": 30
        }
    },
    {
        "sale_id": 22,
        "car_id": 12,
        "customer_id": 11,
        "sale_date": "3/16/24",
        "price": 22500.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 3,
            "first_name": "David",
            "last_name": "Clark",
            "email": "david.clark@example.com",
            "phone": "555-2345",
            "hire_date": "4/12/21",
            "total_sales": 25
        }
    },
    {
        "sale_id": 23,
        "car_id": 21,
        "customer_id": 12,
        "sale_date": "3/17/24",
        "price": 18000.00,
        "payment_method": "Financing",
        "salesperson": {
            "salesperson_id": 1,
            "first_name": "Alice",
            "last_name": "Brown",
            "email": "alice.brown@example.com",
            "phone": "555-1111",
            "hire_date": "5/1/19",
            "total_sales": 50
        }
    },
    {
        "sale_id": 24,
        "car_id": 8,
        "customer_id": 13,
        "sale_date": "3/18/24",
        "price": 23500.00,
        "payment_method": "Bank Transfer",
        "salesperson": {
            "salesperson_id": 4,
            "first_name": "Sophia",
            "last_name": "Martinez",
            "email": "sophia.martinez@example.com",
            "phone": "555-6789",
            "hire_date": "8/24/18",
            "total_sales": 45
        }
    },
    {
        "sale_id": 25,
        "car_id": 3,
        "customer_id": 14,
        "sale_date": "3/19/24",
        "price": 27000.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 5,
            "first_name": "James",
            "last_name": "Moore",
            "email": "james.moore@example.com",
            "phone": "555-5678",
            "hire_date": "2/19/19",
            "total_sales": 60
        }
    },
    {
        "sale_id": 26,
        "car_id": 15,
        "customer_id": 15,
        "sale_date": "3/20/24",
        "price": 25000.00,
        "payment_method": "Credit Card",
        "salesperson": {
            "salesperson_id": 2,
            "first_name": "Bob",
            "last_name": "Johnson",
            "email": "bob.johnson@example.com",
            "phone": "555-2222",
            "hire_date": "6/15/20",
            "total_sales": 30
        }
    },
    {
        "sale_id": 27,
        "car_id": 9,
        "customer_id": 16,
        "sale_date": "3/21/24",
        "price": 21000.00,
        "payment_method": "Financing",
        "salesperson": {
            "salesperson_id": 3,
            "first_name": "David",
            "last_name": "Clark",
            "email": "david.clark@example.com",
            "phone": "555-2345",
            "hire_date": "4/12/21",
            "total_sales": 25
        }
    },
    {
        "sale_id": 28,
        "car_id": 17,
        "customer_id": 17,
        "sale_date": "3/22/24",
        "price": 19500.00,
        "payment_method": "Cash",
        "salesperson": {
            "salesperson_id": 4,
            "first_name": "Sophia",
            "last_name": "Martinez",
            "email": "sophia.martinez@example.com",
            "phone": "555-6789",
            "hire_date": "8/24/18",
            "total_sales": 45
        }
    },
    {
        "sale_id": 29,
        "car_id": 24,
        "customer_id": 18,
        "sale_date": "3/23/24",
        "price": 23000.00,
        "payment_method": "Bank Transfer",
        "salesperson": {
            "salesperson_id": 1,
            "first_name": "Alice",
            "last_name": "Brown",
            "email": "alice.brown@example.com",
            "phone": "555-1111",
            "hire_date": "5/1/19",
            "total_sales": 50
        }
    },
    {
        "sale_id": 30,
        "car_id": 6,
        "customer_id": 19,
        "sale_date": "3/24/24",
        "price": 24000.00,
        "payment_method": "Credit Card",
        "salesperson": {
            "salesperson_id": 5,
            "first_name": "James",
            "last_name": "Moore",
            "email": "james.moore@example.com",
            "phone": "555-5678",
            "hire_date": "2/19/19",
            "total_sales": 60
        }
    }

]

sales.insert_many(sales_data)
# Out:
# InsertManyResult([ObjectId('6750e5bba07ee9b74479ee1b'), ObjectId('6750e5bba07ee9b74479ee1c'), ObjectId('6750e5bba07ee9b74479ee1d'), ObjectId('6750e5bba07ee9b74479ee1e'), ObjectId('6750e5bba07ee9b74479ee1f'), ObjectId('6750e5bba07ee9b74479ee20'), ObjectId('6750e5bba07ee9b74479ee21'), ObjectId('6750e5bba07ee9b74479ee22'), ObjectId('6750e5bba07ee9b74479ee23'), ObjectId('6750e5bba07ee9b74479ee24'), ObjectId('6750e5bba07ee9b74479ee25'), ObjectId('6750e5bba07ee9b74479ee26'), ObjectId('6750e5bba07ee9b74479ee27'), ObjectId('6750e5bba07ee9b74479ee28'), ObjectId('6750e5bba07ee9b74479ee29'), ObjectId('6750e5bba07ee9b74479ee2a'), ObjectId('6750e5bba07ee9b74479ee2b'), ObjectId('6750e5bba07ee9b74479ee2c'), ObjectId('6750e5bba07ee9b74479ee2d'), ObjectId('6750e5bba07ee9b74479ee2e'), ObjectId('6750e5bba07ee9b74479ee2f'), ObjectId('6750e5bba07ee9b74479ee30'), ObjectId('6750e5bba07ee9b74479ee31'), ObjectId('6750e5bba07ee9b74479ee32'), ObjectId('6750e5bba07ee9b74479ee33'), ObjectId('6750e5bba07ee9b74479
# ...

# %% [markdown]
# # Insert inventory items with embedded supplier details

# %%
inventory_data=[
    {
        "inventory_id": 1,
        "car_id": 1,
        "purchase_date": "1/20/20",
        "purchase_price": 18000,
        "quantity": 10,
        "arrival_date": "1/25/20",
        "location": "Lot 1",
        "supplier": {
            "supplier_id": 1,
            "supplier_name": "AutoSupply Inc.",
            "contact_name": "Tom White",
            "email": "tom.white@autosupply.com",
            "phone": "555-3333",
            "address": "500 Industrial Rd, Cityville"
        }
    },
    {
        "inventory_id": 2,
        "car_id": 3,
        "purchase_date": "2/10/22",
        "purchase_price": 75000,
        "quantity": 5,
        "arrival_date": "2/15/22",
        "location": "Lot 2",
        "supplier": {
            "supplier_id": 2,
            "supplier_name": "Parts4U",
            "contact_name": "Sue Green",
            "email": "sue.green@parts4u.com",
            "phone": "555-4444",
            "address": "123 Commerce Ave, Cityville"
        }
    },
    {
        "inventory_id": 3,
        "car_id": 2,
        "purchase_date": "7/18/21",
        "purchase_price": 32000,
        "quantity": 8,
        "arrival_date": "7/20/21",
        "location": "Lot 3",
        "supplier": {
            "supplier_id": 1,
            "supplier_name": "AutoSupply Inc.",
            "contact_name": "Tom White",
            "email": "tom.white@autosupply.com",
            "phone": "555-3333",
            "address": "500 Industrial Rd, Cityville"
        }
    },
    {
        "inventory_id": 4,
        "car_id": 4,
        "purchase_date": "1/12/23",
        "purchase_price": 17000,
        "quantity": 15,
        "arrival_date": "1/18/23",
        "location": "Lot 4",
        "supplier": {
            "supplier_id": 1,
            "supplier_name": "AutoSupply Inc.",
            "contact_name": "Tom White",
            "email": "tom.white@autosupply.com",
            "phone": "555-3333",
            "address": "500 Industrial Rd, Cityville"
        }
    },
    {
        "inventory_id": 5,
        "car_id": 5,
        "purchase_date": "3/5/23",
        "purchase_price": 39000,
        "quantity": 7,
        "arrival_date": "3/10/23",
        "location": "Lot 5",
        "supplier": {
            "supplier_id": 2,
            "supplier_name": "Parts4U",
            "contact_name": "Sue Green",
            "email": "sue.green@parts4u.com",
            "phone": "555-4444",
            "address": "123 Commerce Ave, Cityville"
        }
    },
    {
        "inventory_id": 6,
        "car_id": 3,
        "purchase_date": "5/30/23",
        "purchase_price": 78000,
        "quantity": 3,
        "arrival_date": "6/2/23",
        "location": "Lot 6",
        "supplier": {
            "supplier_id": 2,
            "supplier_name": "Parts4U",
            "contact_name": "Sue Green",
            "email": "sue.green@parts4u.com",
            "phone": "555-4444",
            "address": "123 Commerce Ave, Cityville"
        }
    },
    {
        "inventory_id": 7,
        "car_id": 7,
        "purchase_date": "7/14/21",
        "purchase_price": 43000,
        "quantity": 12,
        "arrival_date": "7/20/21",
        "location": "Lot 7",
        "supplier": {
            "supplier_id": 3,
            "supplier_name": "Global Auto Parts",
            "contact_name": "John Doe",
            "email": "john.doe@globalauto.com",
            "phone": "555-9876",
            "address": "789 Industrial Ave, Detroit"
        }
    },
    {
        "inventory_id": 8,
        "car_id": 9,
        "purchase_date": "9/18/22",
        "purchase_price": 68000,
        "quantity": 5,
        "arrival_date": "9/23/22",
        "location": "Lot 8",
        "supplier": {
            "supplier_id": 4,
            "supplier_name": "Prime Auto Supplies",
            "contact_name": "Alice Johnson",
            "email": "alice.johnson@primeauto.com",
            "phone": "555-3456",
            "address": "456 Commerce Blvd, Houston"
        }
    },
    {
        "inventory_id": 9,
        "car_id": 8,
        "purchase_date": "3/10/21",
        "purchase_price": 52000,
        "quantity": 10,
        "arrival_date": "3/15/21",
        "location": "Lot 9",
        "supplier": {
            "supplier_id": 5,
            "supplier_name": "Vehicle Source Inc.",
            "contact_name": "Mike Brown",
            "email": "mike.brown@vehiclesource.com",
            "phone": "555-8765",
            "address": "123 Business St, Los Angeles"
        }
    },
    {
        "inventory_id": 10,
        "car_id": 6,
        "purchase_date": "12/24/20",
        "purchase_price": 59000,
        "quantity": 15,
        "arrival_date": "12/30/20",
        "location": "Lot 10",
        "supplier": {
            "supplier_id": 6,
            "supplier_name": "Reliable Car Parts",
            "contact_name": "Nancy White",
            "email": "nancy.white@reliableparts.com",
            "phone": "555-4321",
            "address": "999 Supply Rd, Miami"
        }
    },
    {
        "inventory_id": 11,
        "car_id": 14,
        "purchase_date": "11/10/19",
        "purchase_price": 17000,
        "quantity": 20,
        "arrival_date": "11/15/19",
        "location": "Lot 11",
        "supplier": {
            "supplier_id": 7,
            "supplier_name": "AutoNation Suppliers",
            "contact_name": "Tom Green",
            "email": "tom.green@autonation.com",
            "phone": "555-5670",
            "address": "78 Manufacturing Dr, Chicago"
        }
    },
    {
        "inventory_id": 12,
        "car_id": 11,
        "purchase_date": "1/15/22",
        "purchase_price": 24000,
        "quantity": 6,
        "arrival_date": "1/20/22",
        "location": "Lot 12",
        "supplier": {
            "supplier_id": 3,
            "supplier_name": "Global Auto Parts",
            "contact_name": "John Doe",
            "email": "john.doe@globalauto.com",
            "phone": "555-9876",
            "address": "789 Industrial Ave, Detroit"
        }
    },
    {
        "inventory_id": 13,
        "car_id": 12,
        "purchase_date": "8/14/22",
        "purchase_price": 51000,
        "quantity": 8,
        "arrival_date": "8/20/22",
        "location": "Lot 13",
        "supplier": {
            "supplier_id": 4,
            "supplier_name": "Prime Auto Supplies",
            "contact_name": "Alice Johnson",
            "email": "alice.johnson@primeauto.com",
            "phone": "555-3456",
            "address": "456 Commerce Blvd, Houston"
        }
    },
    {
        "inventory_id": 14,
        "car_id": 13,
        "purchase_date": "5/25/21",
        "purchase_price": 28000,
        "quantity": 7,
        "arrival_date": "5/30/21",
        "location": "Lot 14",
        "supplier": {
            "supplier_id": 5,
            "supplier_name": "Vehicle Source Inc.",
            "contact_name": "Mike Brown",
            "email": "mike.brown@vehiclesource.com",
            "phone": "555-8765",
            "address": "123 Business St, Los Angeles"
        }
    },
    {
        "inventory_id": 15,
        "car_id": 15,
        "purchase_date": "2/10/23",
        "purchase_price": 22000,
        "quantity": 9,
        "arrival_date": "2/16/23",
        "location": "Lot 15",
        "supplier": {
            "supplier_id": 6,
            "supplier_name": "Reliable Car Parts",
            "contact_name": "Nancy White",
            "email": "nancy.white@reliableparts.com",
            "phone": "555-4321",
            "address": "999 Supply Rd, Miami"
        }
    },
    {
        "inventory_id": 16,
        "car_id": 10,
        "purchase_date": "10/5/21",
        "purchase_price": 33000,
        "quantity": 4,
        "arrival_date": "10/10/21",
        "location": "Lot 16",
        "supplier": {
            "supplier_id": 7,
            "supplier_name": "AutoNation Suppliers",
            "contact_name": "Tom Green",
            "email": "tom.green@autonation.com",
            "phone": "555-5670",
            "address": "78 Manufacturing Dr, Chicago"
        }
    },
    {
        "inventory_id": 17,
        "car_id": 5,
        "purchase_date": "1/10/24",
        "purchase_price": 18500,
        "quantity": 10,
        "arrival_date": "1/15/24",
        "location": "Lot 11",
        "supplier": {
            "supplier_id": 2,
            "supplier_name": "Parts4U",
            "contact_name": "Sue Green",
            "email": "sue.green@parts4u.com",
            "phone": "555-4444",
            "address": "123 Commerce Ave, Cityville"
        }
    },
    {
        "inventory_id": 18,
        "car_id": 12,
        "purchase_date": "1/12/24",
        "purchase_price": 21500,
        "quantity": 8,
        "arrival_date": "1/17/24",
        "location": "Lot 12",
        "supplier": {
            "supplier_id": 3,
            "supplier_name": "Global Auto Parts",
            "contact_name": "John Doe",
            "email": "john.doe@globalauto.com",
            "phone": "555-9876",
            "address": "789 Industrial Ave, Detroit"
        }
    },
     {
        "inventory_id": 19,
        "car_id": 21,
        "purchase_date": "1/15/24",
        "purchase_price": 17500,
        "quantity": 5,
        "arrival_date": "1/20/24",
        "location": "Lot 3",
        "supplier": {
            "supplier_id": 1,
            "supplier_name": "AutoSupply Inc.",
            "contact_name": "Tom White",
            "email": "tom.white@autosupply.com",
            "phone": "555-3333",
            "address": "500 Industrial Rd, Cityville"
        }
    },
    {
        "inventory_id": 20,
        "car_id": 8,
        "purchase_date": "1/18/24",
        "purchase_price": 22500,
        "quantity": 6,
        "arrival_date": "1/22/24",
        "location": "Lot 14",
        "supplier": {
            "supplier_id": 4,
            "supplier_name": "Prime Auto Supplies",
            "contact_name": "Alice Johnson",
            "email": "alice.johnson@primeauto.com",
            "phone": "555-3456",
            "address": "456 Commerce Blvd, Houston"
        }
    },
    {
        "inventory_id": 21,
        "car_id": 3,
        "purchase_date": "1/20/24",
        "purchase_price": 26000,
        "quantity": 12,
        "arrival_date": "1/25/24",
        "location": "Lot 5",
        "supplier": {
            "supplier_id": 5,
            "supplier_name": "Vehicle Source Inc.",
            "contact_name": "Mike Brown",
            "email": "mike.brown@vehiclesource.com",
            "phone": "555-8765",
            "address": "123 Business St, Los Angeles"
        }
    },
    {
        "inventory_id": 22,
        "car_id": 15,
        "purchase_date": "1/25/24",
        "purchase_price": 24000,
        "quantity": 7,
        "arrival_date": "1/30/24",
        "location": "Lot 6",
        "supplier": {
            "supplier_id": 2,
            "supplier_name": "Parts4U",
            "contact_name": "Sue Green",
            "email": "sue.green@parts4u.com",
            "phone": "555-4444",
            "address": "123 Commerce Ave, Cityville"
        }
    },
    {
        "inventory_id": 23,
        "car_id": 9,
        "purchase_date": "1/30/24",
        "purchase_price": 20500,
        "quantity": 9,
        "arrival_date": "2/5/24",
        "location": "Lot 17",
        "supplier": {
            "supplier_id": 3,
            "supplier_name": "Global Auto Parts",
            "contact_name": "John Doe",
            "email": "john.doe@globalauto.com",
            "phone": "555-9876",
            "address": "789 Industrial Ave, Detroit"
        }
    },
    {
        "inventory_id": 24,
        "car_id": 17,
        "purchase_date": "2/2/24",
        "purchase_price": 19500,
        "quantity": 4,
        "arrival_date": "2/8/24",
        "location": "Lot 8",
        "supplier": {
            "supplier_id": 1,
            "supplier_name": "AutoSupply Inc.",
            "contact_name": "Tom White",
            "email": "tom.white@autosupply.com",
            "phone": "555-3333",
            "address": "500 Industrial Rd, Cityville"
        }
    },
    {
        "inventory_id": 25,
        "car_id": 24,
        "purchase_date": "2/5/24",
        "purchase_price": 23000,
        "quantity": 3,
        "arrival_date": "2/10/24",
        "location": "Lot 9",
        "supplier": {
            "supplier_id": 4,
            "supplier_name": "Prime Auto Supplies",
            "contact_name": "Alice Johnson",
            "email": "alice.johnson@primeauto.com",
            "phone": "555-3456",
            "address": "456 Commerce Blvd, Houston"
        }
    },
    {
        "inventory_id": 26,
        "car_id": 6,
        "purchase_date": "2/10/24",
        "purchase_price": 24500,
        "quantity": 2,
        "arrival_date": "2/15/24",
        "location": "Lot 11",
        "supplier": {
            "supplier_id": 5,
            "supplier_name": "Vehicle Source Inc.",
            "contact_name": "Mike Brown",
            "email": "mike.brown@vehiclesource.com",
            "phone": "555-8765",
            "address": "123 Business St, Los Angeles"
        }
    }
]

inventory.insert_many(inventory_data)
# Out:
# InsertManyResult([ObjectId('6750e5d6a07ee9b74479ee39'), ObjectId('6750e5d6a07ee9b74479ee3a'), ObjectId('6750e5d6a07ee9b74479ee3b'), ObjectId('6750e5d6a07ee9b74479ee3c'), ObjectId('6750e5d6a07ee9b74479ee3d'), ObjectId('6750e5d6a07ee9b74479ee3e'), ObjectId('6750e5d6a07ee9b74479ee3f'), ObjectId('6750e5d6a07ee9b74479ee40'), ObjectId('6750e5d6a07ee9b74479ee41'), ObjectId('6750e5d6a07ee9b74479ee42'), ObjectId('6750e5d6a07ee9b74479ee43'), ObjectId('6750e5d6a07ee9b74479ee44'), ObjectId('6750e5d6a07ee9b74479ee45'), ObjectId('6750e5d6a07ee9b74479ee46'), ObjectId('6750e5d6a07ee9b74479ee47'), ObjectId('6750e5d6a07ee9b74479ee48'), ObjectId('6750e5d6a07ee9b74479ee49'), ObjectId('6750e5d6a07ee9b74479ee4a'), ObjectId('6750e5d6a07ee9b74479ee4b'), ObjectId('6750e5d6a07ee9b74479ee4c'), ObjectId('6750e5d6a07ee9b74479ee4d'), ObjectId('6750e5d6a07ee9b74479ee4e'), ObjectId('6750e5d6a07ee9b74479ee4f'), ObjectId('6750e5d6a07ee9b74479ee50'), ObjectId('6750e5d6a07ee9b74479ee51'), ObjectId('6750e5d6a07ee9b74479
# ...

# %%
# Access the 'car' collection from the database
cars = db['cars']

# Fetching all documents in the 'car' collection
for car_variable in cars.find():
    print(car_variable)
# Out:
# {'_id': ObjectId('6750e49ba07ee9b74479edc8'), 'car_id': 1, 'year': 2020, 'price': 20000.0, 'color': 'White', 'vin': 'JTMZK33V876009879', 'stock_status': 'Available', 'mileage': 15000, 'model': {'model_id': 1, 'make': 'Toyota', 'model': 'Corolla', 'engine_type': 'Gasoline'}}
# {'_id': ObjectId('6750e49ba07ee9b74479edc9'), 'car_id': 2, 'year': 2021, 'price': 35000.0, 'color': 'Red', 'vin': '1ZVBP8CF6B5123456', 'stock_status': 'Sold', 'mileage': 5000, 'model': {'model_id': 2, 'make': 'Ford', 'model': 'Mustang', 'engine_type': 'Gasoline'}}
# {'_id': ObjectId('6750e49ba07ee9b74479edca'), 'car_id': 3, 'year': 2022, 'price': 80000.0, 'color': 'Black', 'vin': '5YJSA1E25FF100001', 'stock_status': 'In Stock', 'mileage': 1200, 'model': {'model_id': 3, 'make': 'Tesla', 'model': 'Model S', 'engine_type': 'Electric'}}
# ...

# %%
#fetching all data in service
for service in services.find():
    print(service)
# Out:
# {'_id': ObjectId('6750e54aa07ee9b74479ee0a'), 'service_id': 1, 'car_id': 1, 'customer_id': 1, 'service_date': '3/1/21', 'service_type': 'Oil Change', 'cost': 50, 'technician': {'technician_id': 1, 'first_name': 'Mike', 'last_name': 'Wrench', 'email': 'mike.wrench@carservice.com', 'phone_number': '555-5555', 'specialty': 'Engine Repair'}}
# {'_id': ObjectId('6750e54aa07ee9b74479ee0b'), 'service_id': 2, 'car_id': 2, 'customer_id': 2, 'service_date': '4/12/22', 'service_type': 'Tire Rotation', 'cost': 30, 'technician': {'technician_id': 2, 'first_name': 'Sam', 'last_name': 'Fixer', 'email': 'sam.fixer@carservice.com', 'phone_number': '555-6666', 'specialty': 'Electrical'}}
# ...

# %%
#fetching all data in sales
for sale in sales.find():
    print(sale)
# Out:
# {'_id': ObjectId('6750e5bba07ee9b74479ee1b'), 'sale_id': 1, 'car_id': 2, 'customer_id': 1, 'sale_date': '8/21/21', 'price': 35000.0, 'payment_method': 'Cash', 'salesperson': {'salesperson_id': 1, 'first_name': 'Alice', 'last_name': 'Brown', 'email': 'alice.brown@example.com', 'phone': '555-1111', 'hire_date': '5/1/19', 'total_sales': 50}}
# {'_id': ObjectId('6750e5bba07ee9b74479ee1c'), 'sale_id': 2, 'car_id': 3, 'customer_id': 2, 'sale_date': '1/15/22', 'price': 80000.0, 'payment_method': 'Financing', 'salesperson': {'salesperson_id': 2, 'first_name': 'Bob', 'last_name': 'Johnson', 'email': 'bob.johnson@example.com', 'phone': '555-2222', 'hire_date': '6/15/20', 'total_sales': 30}}
# ...

# %%
#fetching all data in inventory
for inv in inventory.find():
    print(inv)
# Out:
# {'_id': ObjectId('6750e5d6a07ee9b74479ee39'), 'inventory_id': 1, 'car_id': 1, 'purchase_date': '1/20/20', 'purchase_price': 18000, 'quantity': 10, 'arrival_date': '1/25/20', 'location': 'Lot 1', 'supplier': {'supplier_id': 1, 'supplier_name': 'AutoSupply Inc.', 'contact_name': 'Tom White', 'email': 'tom.white@autosupply.com', 'phone': '555-3333', 'address': '500 Industrial Rd, Cityville'}}
# {'_id': ObjectId('6750e5d6a07ee9b74479ee3a'), 'inventory_id': 2, 'car_id': 3, 'purchase_date': '2/10/22', 'purchase_price': 75000, 'quantity': 5, 'arrival_date': '2/15/22', 'location': 'Lot 2', 'supplier': {'supplier_id': 2, 'supplier_name': 'Parts4U', 'contact_name': 'Sue Green', 'email': 'sue.green@parts4u.com', 'phone': '555-4444', 'address': '123 Commerce Ave, Cityville'}}
# ...

# %%
# Query 1: Update a Single Document of Cars Collection by its unique VIN number
cars.update_one(
    {"vin": "JTMZK33V876009879"},  # Filter to find the document with vin
    {"$set": {"mileage": "24000"}}  # Update the 'mileage' field 15000 to "24000"
)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000001ba'), 'opTime': {'ts': Timestamp(1733425510, 98), 't': 442}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1733425510, 98), 'signature': {'hash': b'\xd3\x9cL\xe8|V\x16\x92\xbf\xe1w\xa1WA\xbd\xe0+7p\xcc', 'keyId': 7389728499646332949}}, 'operationTime': Timestamp(1733425510, 98), 'updatedExisting': True}, acknowledged=True)

# %%
# Fetch the updated document
updated_car = cars.find_one({"vin": "JTMZK33V876009879"})
print(updated_car)
# Out:
# {'_id': ObjectId('6750e49ba07ee9b74479edc8'), 'car_id': 1, 'year': 2020, 'price': 20000.0, 'color': 'White', 'vin': 'JTMZK33V876009879', 'stock_status': 'Available', 'mileage': '24000', 'model': {'model_id': 1, 'make': 'Toyota', 'model': 'Corolla', 'engine_type': 'Gasoline'}}

# %%
# Query 2: Delete one document specified by objectID from Cars Collection
from bson import ObjectId  # Ensure ObjectId is imported

# Specify the _id of the car document to delete
car_id = ObjectId("6750e49ba07ee9b74479edca")

result = cars.delete_one({"_id": car_id})

# Check if the document was deleted
if result.deleted_count > 0:
    print("Car deleted successfully.")
else:
    print("No car found with the specified _id.")
# Out:
# Car deleted successfully.

# %%
# Query 3: Filters records where the location is "Lot 6", groups them according to the same location, and sums the total quantity for that location

pipeline = [{'$match': {'location': 'Lot 6'}}, 
            {'$group': {'_id': '$location', 'total_quantity': {'$sum': '$quantity'}}} ]

result = inventory.aggregate(pipeline)
for doc in result:
    print(doc)
# Out:
# {'_id': 'Lot 6', 'total_quantity': 10}

# %%
# Query 4:  Count the total number of cars by year in ascending order using the Aggregate function
pipeline = [
    {"$group": {"_id": "$year", "count": {"$sum": 1}}},  # Group by year and count cars
    {"$sort": {"_id": 1}}  # Optional: Sort the results by year in ascending order
]

result = cars.aggregate(pipeline)

# Print the results
for doc in result:
    print(f"Year: {doc['_id']}, Count: {doc['count']}")
# Out:
# Year: 2017, Count: 1
# Year: 2018, Count: 2
# Year: 2019, Count: 4
# Year: 2020, Count: 4
# Year: 2021, Count: 27
# Year: 2022, Count: 27

# %%
# Query 5: Retrieve car data along with their associated sales information, and include cars even if they have no sales using $lookup
pipeline = [
    {
        "$lookup": {
            "from": "sales",           # The name of the collection to join (sales)
            "localField": "car_id",    # Field in the cars collection
            "foreignField": "car_id",  # Field in the sales collection that references car_id
            "as": "sales_info"         # The name of the new array field in the cars collection containing matching sales data
        }
    },
    {
        "$unwind": {                  # Unwind the array to get one document per sale
            "path": "$sales_info",   # Path to the array field created by $lookup
            "preserveNullAndEmptyArrays": True  # If no matching sales, include the car document with null sales
        }
    }
]

result = cars.aggregate(pipeline)

# Print the result of the join
for doc in result:
    print(doc)
# Out:
# {'_id': ObjectId('6750e49ba07ee9b74479edc8'), 'car_id': 1, 'year': 2020, 'price': 20000.0, 'color': 'White', 'vin': 'JTMZK33V876009879', 'stock_status': 'Available', 'mileage': '24000', 'model': {'model_id': 1, 'make': 'Toyota', 'model': 'Corolla', 'engine_type': 'Gasoline'}, 'sales_info': {'_id': ObjectId('6750e5bba07ee9b74479ee1d'), 'sale_id': 3, 'car_id': 1, 'customer_id': 4, 'sale_date': '3/18/23', 'price': 20000.0, 'payment_method': 'Cash', 'salesperson': {'salesperson_id': 1, 'first_name': 'Alice', 'last_name': 'Brown', 'email': 'alice.brown@example.com', 'phone': '555-1111', 'hire_date': '5/1/19', 'total_sales': 50}}}
# ...

# %%
# Query 6: Calculate the average service cost for each car, including the location, based on data from the services and inventory collection
pipeline = [
    {"$lookup": {
            "from": "services",           # Join with the 'services' collection
            "localField": "car_id",       # Match 'car_id' in 'inventory'
            "foreignField": "car_id",     # Match 'car_id' in 'services'
            "as": "service_details"       # Add matching services as an array
        }},
    {"$unwind": {
            "path": "$service_details",   # Flatten the service details array
            "preserveNullAndEmptyArrays": False  # Exclude cars with no services
        }},
    {"$group": {
            "_id": "$car_id",            # Group by car_id
            "avg_service_cost": { "$avg": "$service_details.cost" },  # Calculate average cost
            "location": { "$first": "$location" }  # Include the car's location from inventory
        }},
    {"$sort": { "avg_service_cost": -1 }  # Sort by average cost (descending)
    }]
result = inventory.aggregate(pipeline)
for doc in result:                # Print the results
    print(f"Car ID: {doc['_id']}, Location: {doc['location']}, Avg Service Cost: {doc['avg_service_cost']}")
# Out:
# Car ID: 14, Location: Lot 11, Avg Service Cost: 700.0
# Car ID: 6, Location: Lot 10, Avg Service Cost: 600.0
# Car ID: 13, Location: Lot 14, Avg Service Cost: 500.0
# Car ID: 5, Location: Lot 5, Avg Service Cost: 400.0
# Car ID: 2, Location: Lot 3, Avg Service Cost: 265.0
# Car ID: 15, Location: Lot 15, Avg Service Cost: 200.0
# Car ID: 9, Location: Lot 8, Avg Service Cost: 180.0
# Car ID: 7, Location: Lot 7, Avg Service Cost: 150.0
# Car ID: 4, Location: Lot 4, Avg Service Cost: 150.0
# Car ID: 8, Location: Lot 9, Avg Service Cost: 120.0
# Car ID: 3, Location: Lot 2, Avg Service Cost: 100.0
# Car ID: 12, Location: Lot 13, Avg Service Cost: 80.0
# Car ID: 10, Location: Lot 16, Avg Service Cost: 60.0
# Car ID: 1, Location: Lot 1, Avg Service Cost: 50.0
# Car ID: 11, Location: Lot 12, Avg Service Cost: 50.0

# %%
# Query 7: Finds records where the payment method is "Credit Card" and the price is greater than 40000

sales_find = db.sales.find({"$and": [{"payment_method": {"$eq": "Credit Card"}},{"price": {"$gt": 40000}}]})

for car in sales_find:
    payment_method = car["payment_method"]
    price = car["price"]
    print(f"Payment Options: {payment_method}, Price: {price}")
# Out:
# Payment Options: Credit Card, Price: 54000.0
# Payment Options: Credit Card, Price: 52000.0

# %%
# Query 8: It filters records based on 2 criteria: Price > 100 and records containg "Oil Change" or "Battery Replacement" 
# as a service type

services_find = db.services.find({"$or": [{"service_type": {"$in": ["Oil Change", "Battery Replacement"]}},{"cost": {"$gt": 100}}]})

for car in services_find:
    service_type = car["service_type"]
    price = car["cost"]
    print(f"Services: {service_type}, Price: {price}")
# Out:
# Services: Oil Change, Price: 50
# Services: Battery Replacement, Price: 150
# Services: Transmission Repair, Price: 400
# Services: Oil Change, Price: 50
# Services: Engine Repair, Price: 500
# Services: Tire Replacement, Price: 150
# Services: Battery Replacement, Price: 180
# Services: Brake Service, Price: 120
# Services: Engine Repair, Price: 600
# Services: Transmission Repair, Price: 700
# Services: Suspension Repair, Price: 500
# Services: Coolant Flush, Price: 200
